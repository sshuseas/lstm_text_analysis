# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime as dt
import os

# %%
path = '/Users/sagehuseas/Desktop/aiRev/exploratory/'

# %%
os.chdir(path)

# %%
df1 = pd.read_csv('data/Feinstein_Andrea_text.csv')
df2 = pd.read_csv('data/SageHuseas_confidential.csv')
stocks = pd.read_csv('data/CSV.csv')

# %%
af_perf = df2[df2.pm == 'Feinstein_Andrea']

# %%
af_2007 = af_perf[af_perf.year == 2007]

# %%
af_2007.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1603 entries, 0 to 1602
# Data columns (total 48 columns):
# active_positions             1603 non-null int64
# comnam                       1559 non-null object
# date                         1603 non-null object
# DaysInPosition               1603 non-null int64
# DaysInPositionAvg_port       1603 non-null float64
# entries_total                1603 non-null int64
# eq_size_decile               1559 non-null float64
# exits_total                  1603 non-null int64
# gmv                          1603 non-null float64
# gmv_port                     1603 non-null int64
# L.loggmv_port                1602 non-null float64
# L.logmktcap                  1559 non-null float64
# L.PnL_port                   1602 non-null float64
# leverage_port                1603 non-null float64
# loggmv_port                  1603 non-null float64
# logmktcap                    1559 non-null float64
# ...

# %%
plt.scatter(stocks.)

# %%
plt.scatter(af_2007.date, af_2007.returns_raw)

# %%
sns.barplot(af_2007.date, af_2007.returns_raw)

# %%
df1.head()
# Out:
#    sentence_id  convo_id            datestamp               from  \
# 0       7960.0      13.0  2010-04-05 08:01:26  diamondbackenergy
# 1       7961.0      13.0  2010-04-05 08:04:00  diamondbackenergy
# 2       7962.0      13.0  2010-04-05 08:31:13  diamondbackenergy
# 3       7963.0      13.0  2010-04-05 08:36:11  diamondbackenergy
# 4       7964.0      13.0  2010-04-05 08:44:17  diamondbackenergy
#
#                  to  from_internal  to_internal  \
# 0  Feinstein_Andrea            0.0          1.0
# 1  Feinstein_Andrea            0.0          1.0
# 2  Feinstein_Andrea            0.0          1.0
# 3  Feinstein_Andrea            0.0          1.0
# 4  Feinstein_Andrea            0.0          1.0
#
#                                                 text  \
# 0  [jphickeyjpmc]:SD  Arb Desk desk bidding 7.30 ...
# 1                         [givner55]:we are buyer SD
# 2  [bdurandmacq]:Smallcap/Midcap top picks - Mont...
# 3  [friedlanderrlf]:*Technical:  Seasonal + bias ...
# ...

# %%
af_perf.date = pd.to_datetime(af_perf.date)
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
df1.datestamp.dropna(inplace=True)

# %%
df1.datestamp = pd.to_datetime(df1.datestamp)

# %%
df1.datestamp.min()
# Out:
# Timestamp('2007-08-30 07:54:03')

# %%
af_perf.date.min()
# Out:
# Timestamp('2007-09-10 00:00:00')

# %%
df1.dropna(inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433948 entries, 0 to 436131
# Data columns (total 9 columns):
# sentence_id      433948 non-null float64
# convo_id         433948 non-null float64
# datestamp        433948 non-null datetime64[ns]
# from             433948 non-null object
# to               433948 non-null object
# from_internal    433948 non-null float64
# to_internal      433948 non-null float64
# text             433948 non-null object
# tagged_text      433948 non-null object
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 33.1+ MB

# %%
df1['date'] = df1.datestamp.dt.date

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 433948 entries, 0 to 436131
# Data columns (total 10 columns):
# sentence_id      433948 non-null float64
# convo_id         433948 non-null float64
# datestamp        433948 non-null datetime64[ns]
# from             433948 non-null object
# to               433948 non-null object
# from_internal    433948 non-null float64
# to_internal      433948 non-null float64
# text             433948 non-null object
# tagged_text      433948 non-null object
# date             433948 non-null object
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 36.4+ MB

# %%
af_perf1 = af_perf.select_dtypes(exclude=object)

# %%
af_perf1.set_index('date', inplace=True)

# %%
df1.set_index('date')
# Out:
#             sentence_id  convo_id           datestamp               from  \
# date
# 2010-04-05       7960.0      13.0 2010-04-05 08:01:26  diamondbackenergy
# 2010-04-05       7961.0      13.0 2010-04-05 08:04:00  diamondbackenergy
# 2010-04-05       7962.0      13.0 2010-04-05 08:31:13  diamondbackenergy
# 2010-04-05       7963.0      13.0 2010-04-05 08:36:11  diamondbackenergy
# 2010-04-05       7964.0      13.0 2010-04-05 08:44:17  diamondbackenergy
# 2010-04-05       7965.0      13.0 2010-04-05 08:51:39  diamondbackenergy
# 2010-04-05       7966.0      13.0 2010-04-05 08:52:31  diamondbackenergy
# 2010-04-05       7967.0      13.0 2010-04-05 08:52:46  diamondbackenergy
# 2010-04-05       7968.0      13.0 2010-04-05 09:01:15  diamondbackenergy
# 2010-04-05       7969.0      13.0 2010-04-05 09:04:53  diamondbackenergy
# 2010-04-05       7970.0      13.0 2010-04-05 09:05:14  diamondbackenergy
# 2010-04-05       7971.0      13.0 2010-04-05 09:06:57  diamondbackenergy
# ...

# %%
af_perf.head()
# Out:
#    active_positions                          comnam       date  \
# 0                 5  AMERICAN ELECTRIC POWER CO INC 2007-09-10
# 1                 5                BLACK HILLS CORP 2007-09-10
# 2                 5   DOMINION RESOURCES INC VA NEW 2007-09-10
# 3                 5                FIRSTENERGY CORP 2007-09-10
# 4                 6  AMERICAN ELECTRIC POWER CO INC 2007-09-11
#
#    DaysInPosition  DaysInPositionAvg_port  entries_total  eq_size_decile  \
# 0               1                1.000000              5             9.0
# 1               1                1.000000              5             4.0
# 2               1                1.000000              5             9.0
# 3               1                1.000000              5             9.0
# 4               2                1.833333              1             9.0
#
#    exits_total        gmv  gmv_port    ...      siccd  size_portpct    sprtrn  \
# ...

# %%
df1.head() #need to set df1 index to date from earliest to latest
# Out:
#    sentence_id  convo_id           datestamp               from  \
# 0       7960.0      13.0 2010-04-05 08:01:26  diamondbackenergy
# 1       7961.0      13.0 2010-04-05 08:04:00  diamondbackenergy
# 2       7962.0      13.0 2010-04-05 08:31:13  diamondbackenergy
# 3       7963.0      13.0 2010-04-05 08:36:11  diamondbackenergy
# 4       7964.0      13.0 2010-04-05 08:44:17  diamondbackenergy
#
#                  to  from_internal  to_internal  \
# 0  Feinstein_Andrea            0.0          1.0
# 1  Feinstein_Andrea            0.0          1.0
# 2  Feinstein_Andrea            0.0          1.0
# 3  Feinstein_Andrea            0.0          1.0
# 4  Feinstein_Andrea            0.0          1.0
#
#                                                 text  \
# 0  [jphickeyjpmc]:SD  Arb Desk desk bidding 7.30 ...
# 1                         [givner55]:we are buyer SD
# 2  [bdurandmacq]:Smallcap/Midcap top picks - Mont...
# 3  [friedlanderrlf]:*Technical:  Seasonal + bias ...
# ...
